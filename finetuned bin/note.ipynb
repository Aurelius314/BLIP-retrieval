# %% [markdown]
# {"image": ["https://digitalarchive.npm.gov.tw/Image/GetImage?imageId=628372&randomCode=270134180", "https://digitalarchive.npm.gov.tw/Image/GetImage?imageId=628373&randomCode=209440967", "https://digitalarchive.npm.gov.tw/Image/GetImage?imageId=628374&randomCode=1320620330", "https://digitalarchive.npm.gov.tw/Image/GetImage?imageId=628375&randomCode=1527602291", "https://digitalarchive.npm.gov.tw/Image/GetImage?imageId=628376&randomCode=1946758328", "https://digitalarchive.npm.gov.tw/Image/GetImage?imageId=628377&randomCode=1370593087", "https://digitalarchive.npm.gov.tw/Image/GetImage?imageId=628378&randomCode=1759486574"], "structured": "这里是结构性文本示例", "jianjie": "这里是简介文本示例"}

# %% [markdown]
# (image, text)
#
# num (id) = 2 x len(images)
